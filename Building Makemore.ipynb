# %% [markdown]
# # Building Makemore Part 2
#
# - We are working in the level of the character, but in the paper they are working the level of words
# - 17,000 words-> for each word has a 30 dimentional feature vector
# - random
# - tune imbeding using backpropagation
# - word that would mean the same would end up in the same space
# - maximizing the log liklihood
#
# - a dog was running in a _______
# - never occured in the training set
# - but it could of heard the dog was running in a ____
# - and maybe the and a are in the same space we could use the info from the "the" with the "a"
#
#
#
#
# ![image.png](attachment:933362d7-8e99-42c3-8ce9-d07b3fcb6820.png)
